# %% [markdown]
# <a href="https://colab.research.google.com/github/King-Abbey/My-Python-Learnings/blob/main/My%20Python%20Workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/test.csv', encoding = "ISO8859-1")
df.head
# Out:
# <bound method NDFrame.head of        Unnamed: 0     id  ... Arrival Delay in Minutes             satisfaction
# 0               0  19556  ...                     44.0                satisfied
# 1               1  90035  ...                      0.0                satisfied
# 2               2  12360  ...                      0.0  neutral or dissatisfied
# 3               3  77959  ...                      6.0                satisfied
# 4               4  36875  ...                     20.0                satisfied
# ...           ...    ...  ...                      ...                      ...
# 25971       25971  78463  ...                      0.0  neutral or dissatisfied
# 25972       25972  71167  ...                      0.0                satisfied
# 25973       25973  37675  ...                      0.0  neutral or dissatisfied
# 25974       25974  90086  ...                      0.0                satisfied
# ...

# %%
import pandas
df = pandas.read_csv("/content/test.csv")
print(df)
# Out:
#        Unnamed: 0     id  ... Arrival Delay in Minutes             satisfaction
# 0               0  19556  ...                     44.0                satisfied
# 1               1  90035  ...                      0.0                satisfied
# 2               2  12360  ...                      0.0  neutral or dissatisfied
# 3               3  77959  ...                      6.0                satisfied
# 4               4  36875  ...                     20.0                satisfied
# ...           ...    ...  ...                      ...                      ...
# 25971       25971  78463  ...                      0.0  neutral or dissatisfied
# 25972       25972  71167  ...                      0.0                satisfied
# 25973       25973  37675  ...                      0.0  neutral or dissatisfied
# 25974       25974  90086  ...                      0.0                satisfied
# 25975       25975  34799  ...                      0.0  neutral or dissatisfied
#
# ...

# %%
pandas.set_option('display.max_rows', 10)
df = pandas.read_csv("/content/test.csv")
print(df)
# Out:
#        Unnamed: 0     id  ... Arrival Delay in Minutes             satisfaction
# 0               0  19556  ...                     44.0                satisfied
# 1               1  90035  ...                      0.0                satisfied
# 2               2  12360  ...                      0.0  neutral or dissatisfied
# 3               3  77959  ...                      6.0                satisfied
# 4               4  36875  ...                     20.0                satisfied
# ...           ...    ...  ...                      ...                      ...
# 25971       25971  78463  ...                      0.0  neutral or dissatisfied
# 25972       25972  71167  ...                      0.0                satisfied
# 25973       25973  37675  ...                      0.0  neutral or dissatisfied
# 25974       25974  90086  ...                      0.0                satisfied
# 25975       25975  34799  ...                      0.0  neutral or dissatisfied
#
# ...

# %%
pandas.set_option('display.max_rows', None)
df = pandas.read_csv("/content/test.csv")
print(df)
# Out:
#        Unnamed: 0      id  ... Arrival Delay in Minutes             satisfaction
# 0               0   19556  ...                     44.0                satisfied
# 1               1   90035  ...                      0.0                satisfied
# 2               2   12360  ...                      0.0  neutral or dissatisfied
# 3               3   77959  ...                      6.0                satisfied
# 4               4   36875  ...                     20.0                satisfied
# 5               5   39177  ...                      0.0                satisfied
# 6               6   79433  ...                      0.0                satisfied
# 7               7   97286  ...                     65.0                satisfied
# 8               8   27508  ...                      0.0                satisfied
# 9               9   62482  ...                     14.0                satisfied
# 10             10   47583  ...                     19.0                satisfied
# ...
